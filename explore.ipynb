# %% [markdown]
# # explore the dataset

# %%
import pymongo
import pandas as pd
import os
from pymongo.server_api import ServerApi

# %%
df = pd.read_csv('Data_wheather/Abidjan.csv')

# %%
df
# Out:
#        date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2009-01-01        29        25           0.0     10.2        6
# 1     2009-01-02        29        25           0.0     11.6        6
# 2     2009-01-03        28        26           0.0     11.6        6
# 3     2009-01-04        29        26           0.0     11.6        6
# 4     2009-01-05        29        26           0.0     11.6        6
# ...          ...       ...       ...           ...      ...      ...
# 4894  2022-05-27        28        24           0.0     10.2        6
# 4895  2022-05-28        31        26           0.0     10.2        6
# 4896  2022-05-29        28        26           0.0     10.2        6
# 4897  2022-05-30        29        26           0.0      7.5        6
# 4898  2022-05-31        31        26           0.0     10.2        6
#
#       moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
df1 = pd.read_csv('Data_wheather/Athens.csv')

# %%
df1
# Out:
#        date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2009-01-01        12         3           0.0      9.8        3
# 1     2009-01-02        14         6           0.0      9.8        4
# 2     2009-01-03        14        10           0.0      6.6        3
# 3     2009-01-04        13         9           0.0      8.2        3
# 4     2009-01-05        12         8           0.0      4.9        3
# ...          ...       ...       ...           ...      ...      ...
# 4894  2022-05-27        34        23           0.0      9.4        7
# 4895  2022-05-28        33        23           0.0     11.6        7
# 4896  2022-05-29        31        22           0.0     10.5        6
# 4897  2022-05-30        31        20           0.0     11.6        7
# 4898  2022-05-31        34        20           0.0     11.6        7
#
#       moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
p = os.listdir('Data_wheather')
p.remove('.DS_Store')

# %%
p
# Out:
# ['Barbados.csv',
#  'Havana.csv',
#  'Singapore.csv',
#  'Pattaya.csv',
#  'Toronto.csv',
#  'Djerba.csv',
#  'Madrid.csv',
#  'Hawai.csv',
#  'Beirut.csv',
#  'Zanzibar.csv',
#  'Dubai.csv',
#  'Seville.csv',
#  'Nice.csv',
#  'Marrakech.csv',
#  'Abidjan.csv',
#  'Delhi.csv',
#  'Doha.csv',
#  'Venice.csv',
#  'Warsaw.csv',
#  'Manama.csv',
#  'Kolkata.csv',
#  'Taipei.csv',
#  'Chennai.csv',
#  'Mumbai.csv',
#  'Dubrovnik.csv',
#  'Fiji.csv',
#  'Sofia.csv',
#  'Istanbul.csv',
#  'Miami.csv',
#  'Azores.csv',
#  'Cancun.csv',
#  'Zhuhai.csv',
#  'Sydney.csv',
#  'Jaipur.csv',
#  'Tokyo.csv',
#  'Palu.csv',
#  'Bordeaux.csv',
#  'Fortaleza.csv',
#  'Denpasar.csv',
#  'Phuket.csv',
#  'Florence.csv',
#  'Shenzhen.csv',
#  'Amsterdam.csv',
#  'Antalya.csv',
#  'krakow.csv',
#  'Bogota.csv',
#  'Frankfurt.csv',
#  'Dublin.csv',
#  'Vienna.csv',
#  'Vancouver.csv',
#  'marseille.csv',
#  'Hangzhou.csv',
#  'CapeTown.csv',
#  'Cairo.csv',
#  'Brussels.csv',
#  'Cartagena.csv',
# ...

# %%
os.chdir("Data_wheather")
df3 = pd.concat(map(pd.read_csv,p),ignore_index=True)

# %%
df3
# Out:
#          date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0       2009-01-01        27        26           0.0      7.2        6
# 1       2009-01-02        27        27           0.0      8.7        6
# 2       2009-01-03        27        27           0.0      7.2        6
# 3       2009-01-04        27        27           0.0      8.7        7
# 4       2009-01-05        27        27           0.0      8.7        7
# ...            ...       ...       ...           ...      ...      ...
# 504592  2022-05-27        46        34           0.0     13.8       10
# 504593  2022-05-28        44        34           0.0     13.8        9
# 504594  2022-05-29        46        34           0.0     13.8       10
# 504595  2022-05-30        48        34           0.0     13.8       10
# 504596  2022-05-31        48        35           0.0     13.8       10
#
#         moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
#p.remove('.DS_Store')

# %%
p
# Out:
# ['Barbados.csv',
#  'Havana.csv',
#  'Singapore.csv',
#  'Pattaya.csv',
#  'Toronto.csv',
#  'Djerba.csv',
#  'Madrid.csv',
#  'Hawai.csv',
#  'Beirut.csv',
#  'Zanzibar.csv',
#  'Dubai.csv',
#  'Seville.csv',
#  'Nice.csv',
#  'Marrakech.csv',
#  'Abidjan.csv',
#  'Delhi.csv',
#  'Doha.csv',
#  'Venice.csv',
#  'Warsaw.csv',
#  'Manama.csv',
#  'Kolkata.csv',
#  'Taipei.csv',
#  'Chennai.csv',
#  'Mumbai.csv',
#  'Dubrovnik.csv',
#  'Fiji.csv',
#  'Sofia.csv',
#  'Istanbul.csv',
#  'Miami.csv',
#  'Azores.csv',
#  'Cancun.csv',
#  'Zhuhai.csv',
#  'Sydney.csv',
#  'Jaipur.csv',
#  'Tokyo.csv',
#  'Palu.csv',
#  'Bordeaux.csv',
#  'Fortaleza.csv',
#  'Denpasar.csv',
#  'Phuket.csv',
#  'Florence.csv',
#  'Shenzhen.csv',
#  'Amsterdam.csv',
#  'Antalya.csv',
#  'krakow.csv',
#  'Bogota.csv',
#  'Frankfurt.csv',
#  'Dublin.csv',
#  'Vienna.csv',
#  'Vancouver.csv',
#  'marseille.csv',
#  'Hangzhou.csv',
#  'CapeTown.csv',
#  'Cairo.csv',
#  'Brussels.csv',
#  'Cartagena.csv',
# ...

# %%
df3
# Out:
#          date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0       2009-01-01        27        26           0.0      7.2        6
# 1       2009-01-02        27        27           0.0      8.7        6
# 2       2009-01-03        27        27           0.0      7.2        6
# 3       2009-01-04        27        27           0.0      8.7        7
# 4       2009-01-05        27        27           0.0      8.7        7
# ...            ...       ...       ...           ...      ...      ...
# 504592  2022-05-27        46        34           0.0     13.8       10
# 504593  2022-05-28        44        34           0.0     13.8        9
# 504594  2022-05-29        46        34           0.0     13.8       10
# 504595  2022-05-30        48        34           0.0     13.8       10
# 504596  2022-05-31        48        35           0.0     13.8       10
#
#         moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
df3.to_csv('Data_wheather.csv',index = True)

# %%
data=df3.to_dict(orient="records")

# %%
data
# Out:
# [{'date_time': '2009-01-01',
#   'maxtempC': 27,
#   'mintempC': 26,
#   'totalSnow_cm': 0.0,
#   'sunHour': 7.2,
#   'uvIndex': 6,
#   'moon_illumination': 32,
#   'moonrise': '09:51 AM',
#   'moonset': '10:00 PM',
#   'sunrise': '06:21 AM',
#   'sunset': '05:44 PM',
#   'DewPointC': 23,
#   'FeelsLikeC': 29,
#   'HeatIndexC': 29,
#   'WindChillC': 26,
#   'WindGustKmph': 40,
#   'cloudcover': 55,
#   'humidity': 80,
#   'precipMM': 8.4,
#   'pressure': 1013,
#   'tempC': 27,
#   'visibility': 9,
#   'winddirDegree': 62,
#   'windspeedKmph': 29,
#   'location': 'Barbados'},
#  {'date_time': '2009-01-02',
#   'maxtempC': 27,
#   'mintempC': 27,
#   'totalSnow_cm': 0.0,
#   'sunHour': 8.7,
#   'uvIndex': 6,
#   'moon_illumination': 39,
#   'moonrise': '10:27 AM',
#   'moonset': '10:48 PM',
#   'sunrise': '06:21 AM',
#   'sunset': '05:44 PM',
#   'DewPointC': 23,
#   'FeelsLikeC': 30,
#   'HeatIndexC': 30,
#   'WindChillC': 27,
#   'WindGustKmph': 45,
#   'cloudcover': 52,
# ...
