# %% [markdown]
# ## This Notebook shows how we retrieve data from World Wheather Online api

# %%
kmyg = '7ba187c2020a4c35aa8151959222906'

# %%
ke_md = 'c77e3e4e2a854c29a85224821222806'#221

# %%
key = 'e035a9610b0b32cc8ae270c7f6f18a1b'

# %%
newk = '29bea1eec28e486f998210016222906'

# %%
kdspi ='38fb5a2272f04f2384f105212223006'

# %%
#city

# %%
k = '9d74146487c5463ebe8180843222206'

# %%
from wwo_hist import retrieve_hist_data

# %%
# %pip install wwo-hist
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from wwo_hist import retrieve_hist_data

# %%
import os
os.chdir("Data_wheather")
# Out:
# '/Users/Gassama/pper/Data_wheather'

# %%
FREQUENCY = 24
START_DATE = '01-JAN-2009'
END_DATE = '31-MAY-2022'
API_KEY = ke_md
LOCATION_LIST = ['Guadeloupe', 'Bordeaux', 'Porto', 'Bern', 'Athens', 'Seville']

hist_weather_data = retrieve_hist_data(API_KEY,
                                LOCATION_LIST,
                                START_DATE,
                                END_DATE,
                                FREQUENCY,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Guadeloupe
#
#
# Currently retrieving data for Guadeloupe: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.599050
# Currently retrieving data for Guadeloupe: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:01.181372
# Currently retrieving data for Guadeloupe: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.739503
# Currently retrieving data for Guadeloupe: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.319910
# Currently retrieving data for Guadeloupe: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.876481
# Currently retrieving data for Guadeloupe: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.441644
# Currently retrieving data for Guadeloupe: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.980707
# Currently retrieving data for Guadeloupe: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.581531
# ...

# %%
ci
# Out:
# ['Dublin',
#  'London',
#  'Baku',
#  'Delhi',
#  'Orlando',
#  'Budapest',
#  'Chennai',
#  'Manama',
#  'Antalya',
#  'Macau',
#  'Abidjan',
#  'Marrakech',
#  'Johannesburg',
#  'Osaka',
#  'Melbourne',
#  'Cancun',
#  'Brussels',
#  'Lima',
#  'Sydney',
#  'Manila',
#  'Makkah',
#  'Dakar',
#  'Nairobi',
#  'Munich',
#  'Bogotá',
#  'Seoul',
#  'Milan',
#  'Warsaw',
#  'Prague',
#  'Amman',
#  'Taipei',
#  'Mumbai',
#  'Nice',
#  'Frankfurt',
#  'Edirne',
#  'Beirut',
#  'Djerba',
#  'Rome',
#  'Jakarta',
#  'Miami',
#  'Riyadh',
#  'Fortaleza',
#  'Cairo',
#  'Mecca',
#  'Istanbul',
#  'Dubai',
#  'Vancouver',
#  'Paris',
#  'Doha',
#  'Beijing',
#  'Amsterdam',
#  'Guangzhou',
#  'Zhuhai',
#  'Barcelona',
#  'Vienna',
#  'Phuket',
#  'Hangzhou',
#  'Christchurch',
#  'Agra',
#  'Denpasar',
#  'Sousse',
#  'Jaipur',
#  'Florence',
#  'Bangkok',
#  'Mugla',
#  'Bali',
#  'Burgas',
#  'Venice',
#  'Auckland',
#  'Harare',
#  'Pattaya',
#  'Berlin',
#  'Toronto',
#  'Bucharest',
# ...

# %%
p = os.listdir('../Data_wheather')

# %%
p
# Out:
# ['Singapore.csv',
#  'Pattaya.csv',
#  'Toronto.csv',
#  'Djerba.csv',
#  'Madrid.csv',
#  'Beirut.csv',
#  'Dubai.csv',
#  'Nice.csv',
#  'Marrakech.csv',
#  'Abidjan.csv',
#  'Delhi.csv',
#  'Doha.csv',
#  'Venice.csv',
#  'Warsaw.csv',
#  'Manama.csv',
#  'Kolkata.csv',
#  '.DS_Store',
#  'Taipei.csv',
#  'Chennai.csv',
#  'Mumbai.csv',
#  'Sofia.csv',
#  'Istanbul.csv',
#  'Miami.csv',
#  'Cancun.csv',
#  'Zhuhai.csv',
#  'Sydney.csv',
#  'Jaipur.csv',
#  'Tokyo.csv',
#  'Fortaleza.csv',
#  'Denpasar.csv',
#  'Phuket.csv',
#  'Florence.csv',
#  'Shenzhen.csv',
#  'Amsterdam.csv',
#  'Antalya.csv',
#  'Bogota.csv',
#  'Frankfurt.csv',
#  'Dublin.csv',
#  'Vienna.csv',
#  'Vancouver.csv',
#  'marseille.csv',
#  'Hangzhou.csv',
#  'Cairo.csv',
#  'Brussels.csv',
#  'Baku.csv',
#  'Amman.csv',
#  'Dakar.csv',
#  'Rome.csv',
#  'Macau.csv',
#  'Bucharest.csv',
#  'Guangzhou.csv',
#  'Barcelona.csv',
#  'Auckland.csv',
#  'Mugla.csv',
#  'Prague.csv',
#  'Berlin.csv',
# ...

# %%
len(p)
new = []

# %%
for a in p:
    new.append(a.replace('.csv',''))

# %%
new
# Out:
# ['Singapore',
#  'Pattaya',
#  'Toronto',
#  'Djerba',
#  'Madrid',
#  'Beirut',
#  'Dubai',
#  'Nice',
#  'Marrakech',
#  'Abidjan',
#  'Delhi',
#  'Doha',
#  'Venice',
#  'Warsaw',
#  'Manama',
#  'Kolkata',
#  '.DS_Store',
#  'Taipei',
#  'Chennai',
#  'Mumbai',
#  'Sofia',
#  'Istanbul',
#  'Miami',
#  'Cancun',
#  'Zhuhai',
#  'Sydney',
#  'Jaipur',
#  'Tokyo',
#  'Fortaleza',
#  'Denpasar',
#  'Phuket',
#  'Florence',
#  'Shenzhen',
#  'Amsterdam',
#  'Antalya',
#  'Bogota',
#  'Frankfurt',
#  'Dublin',
#  'Vienna',
#  'Vancouver',
#  'marseille',
#  'Hangzhou',
#  'Cairo',
#  'Brussels',
#  'Baku',
#  'Amman',
#  'Dakar',
#  'Rome',
#  'Macau',
#  'Bucharest',
#  'Guangzhou',
#  'Barcelona',
#  'Auckland',
#  'Mugla',
#  'Prague',
#  'Berlin',
#  'Jakarta',
#  'Orlando',
#  'Johannesburg',
#  'Milan',
#  'Edirne',
#  'Melbourne',
#  'Burgas',
#  'malt',
#  'Budapest',
#  'Seoul',
#  'Nairobi',
#  'Christchurch',
#  'crete',
#  'Bali',
#  'Munich',
#  'Lima',
#  'Shanghai',
# ...

# %%
list(set(ci) - set(new))
# Out:
# ['Makkah', 'Mecca', 'Bogotá']
